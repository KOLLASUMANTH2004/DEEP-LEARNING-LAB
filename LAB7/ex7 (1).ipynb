# %%
import tensorflow_datasets as tfds

dataset, info = tfds.load(
    'cats_vs_dogs',
    data_dir='/content/sample_data/cats_vs_dogs',
    as_supervised=True,
    with_info=True
)

# %%
import os

# List files and directories in the base data directory to understand the structure
data_dir_base = '/content/sample_data/cats_vs_dogs'
print(f"Contents of {data_dir_base}:")
print(os.listdir(data_dir_base))

# Assuming based on common tfds structures, there might be a version subdirectory
# Let's try listing the contents of potential subdirectories as well if found
for item in os.listdir(data_dir_base):
    item_path = os.path.join(data_dir_base, item)
    if os.path.isdir(item_path):
        print(f"\nContents of {item_path}:")
        try:
            print(os.listdir(item_path))
        except Exception as e:
            print(f"Could not list contents: {e}")
# Out:
# Contents of /content/sample_data/cats_vs_dogs:
# ['cats_vs_dogs', 'downloads']
#
# Contents of /content/sample_data/cats_vs_dogs/cats_vs_dogs:
# ['4.0.1']
#
# Contents of /content/sample_data/cats_vs_dogs/downloads:
# ['extracted', 'cats_vs_dogs']

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
import torchvision.transforms as transforms

class CatsVsDogsDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        # List files, filtering for jpg and ensuring they are files (not directories)
        self.image_files = [f for f in os.listdir(data_dir) if f.endswith('.jpg') and os.path.isfile(os.path.join(data_dir, f))]


    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = os.path.join(self.data_dir, self.image_files[idx])
        image = Image.open(img_name).convert('RGB')
        label = 1 if 'cat' in self.image_files[idx] else 0

        if self.transform:
            image = self.transform(image)

        return image, label

# Define transforms
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Instantiate the datasets with the corrected data_dir path
corrected_data_dir = '/content/sample_data/cats_vs_dogs/cats_vs_dogs/4.0.1'

# Although tfds loaded with splits, the extracted data might be in a single directory.
# Let's confirm the number of images found in this directory.
# If all images are in one directory, we might need to split them manually for train/validation
# based on the file names or by using a SubsetRandomSampler later.
# For now, let's create a single dataset from this directory and plan for splitting if necessary.

train_dataset = CatsVsDogsDataset(data_dir=corrected_data_dir, transform=transform)
# Since all images are likely in one directory, let's use a simple split for demonstration.
# In a real scenario, we'd use the info object from tfds.load to get split information.
# For this task, let's create dummy train/validation datasets by splitting the single dataset.
# This is a simplification and might not reflect the true train/validation split of the original dataset.

# Let's check the number of images found first.
if len(train_dataset) == 0:
    print(f"Error: No image files found in {corrected_data_dir}")
else:
    # Perform a simple split (e.g., 80% train, 20% validation)
    train_size = int(0.8 * len(train_dataset))
    validation_size = len(train_dataset) - train_size
    train_dataset, validation_dataset = torch.utils.data.random_split(train_dataset, [train_size, validation_size])


    # Create DataLoaders
    batch_size = 32
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)

    print("PyTorch Datasets and DataLoaders created.")
    print(f"Number of training images found: {len(train_dataset)}")
    print(f"Number of validation images found: {len(validation_dataset)}")
    print(f"Number of training batches: {len(train_loader)}")
    print(f"Number of validation batches: {len(validation_loader)}")
# Out:
# Error: No image files found in /content/sample_data/cats_vs_dogs/cats_vs_dogs/4.0.1

# %%
import os

# List contents of the suspected image directory
suspected_image_dir = '/content/sample_data/cats_vs_dogs/cats_vs_dogs/4.0.1'
print(f"Contents of {suspected_image_dir}:")

try:
    contents = os.listdir(suspected_image_dir)
    print(contents)

    # If there are subdirectories, list their contents too
    for item in contents:
        item_path = os.path.join(suspected_image_dir, item)
        if os.path.isdir(item_path):
            print(f"\nContents of {item_path}:")
            try:
                print(os.listdir(item_path))
            except Exception as e:
                print(f"Could not list contents: {e}")

except FileNotFoundError:
    print(f"Directory not found: {suspected_image_dir}")
except Exception as e:
    print(f"An error occurred while listing contents: {e}")
# Out:
# Contents of /content/sample_data/cats_vs_dogs/cats_vs_dogs/4.0.1:
# ['cats_vs_dogs-train.tfrecord-00014-of-00016', 'cats_vs_dogs-train.tfrecord-00006-of-00016', 'cats_vs_dogs-train.tfrecord-00012-of-00016', 'cats_vs_dogs-train.tfrecord-00000-of-00016', 'label.labels.txt', 'cats_vs_dogs-train.tfrecord-00013-of-00016', 'cats_vs_dogs-train.tfrecord-00011-of-00016', 'cats_vs_dogs-train.tfrecord-00001-of-00016', 'dataset_info.json', 'cats_vs_dogs-train.tfrecord-00002-of-00016', 'cats_vs_dogs-train.tfrecord-00009-of-00016', 'cats_vs_dogs-train.tfrecord-00015-of-00016', 'cats_vs_dogs-train.tfrecord-00003-of-00016', 'cats_vs_dogs-train.tfrecord-00010-of-00016', 'features.json', 'cats_vs_dogs-train.tfrecord-00008-of-00016', 'cats_vs_dogs-train.tfrecord-00004-of-00016', 'cats_vs_dogs-train.tfrecord-00005-of-00016', 'cats_vs_dogs-train.tfrecord-00007-of-00016']

# %%
import torch
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import tensorflow as tf # Import tensorflow to use tf.data.Dataset methods

# Assuming the 'dataset' variable from the previous tfds.load step is available
# and is a dictionary like {'train': tf.data.Dataset}
# Assuming 'info' variable is available from the tfds.load step


# Define transforms (same as before)
transform = transforms.Compose([
    transforms.Lambda(lambda x: torch.from_numpy(x.numpy()).permute(2, 0, 1).float() / 255.0), # Convert TF tensor to PyTorch, permute channels, normalize
    transforms.Resize((128, 128)),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

class TfDatasetToPyTorchIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, tf_dataset, transform=None):
        super().__init__()
        self.tf_dataset = tf_dataset
        self.transform = transform

    def __iter__(self):
        for image, label in self.tf_dataset:
            # Convert TensorFlow tensors to NumPy arrays, then to PyTorch tensors
            image = torch.from_numpy(image.numpy())
            label = torch.tensor(label.numpy())

            # Re-apply transform logic here to work with PyTorch tensor
            # Ensure image is float and has channels first for torchvision transforms
            image = image.permute(2, 0, 1).float() / 255.0 # Convert to channels first and normalize to [0, 1]

            if self.transform:
                 # Apply the rest of the transforms
                 image = transforms.Compose([
                     transforms.Resize((128, 128)),
                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                 ])(image) # Apply the rest of the transforms

            yield image, label

# Get the single 'train' split from the loaded dataset object
full_train_tf_dataset = dataset['train']

# Determine the size of the dataset using the info object
try:
    dataset_size = info.splits['train'].num_examples
except NameError:
     print("Error: 'info' variable not found. Cannot determine dataset size accurately.")
     # Fallback to a large number if info is not available - this is not ideal
     dataset_size = 25000 # A large estimate

print(f"Total number of examples in the 'train' split: {dataset_size}")

# Define the split ratio (e.g., 80% train, 20% validation)
train_ratio = 0.8
train_size = int(train_ratio * dataset_size)
validation_size = dataset_size - train_size

# Split and shuffle the dataset
# Shuffle the training dataset before splitting
BUFFER_SIZE = 1000 # Define a buffer size for shuffling
shuffled_full_train_tf_dataset = full_train_tf_dataset.shuffle(BUFFER_SIZE)

train_tf_dataset = shuffled_full_train_tf_dataset.take(train_size)
validation_tf_dataset = shuffled_full_train_tf_dataset.skip(train_size).take(validation_size)


# Create PyTorch IterableDatasets
train_pytorch_dataset = TfDatasetToPyTorchIterableDataset(tf_dataset=train_tf_dataset, transform=transform)
validation_pytorch_dataset = TfDatasetToPyTorchIterableDataset(tf_dataset=validation_tf_dataset, transform=transform)

# Create DataLoaders
batch_size = 32 # Using the batch_size variable from the context
train_loader = DataLoader(train_pytorch_dataset, batch_size=batch_size) # Removed shuffle=True
validation_loader = DataLoader(validation_pytorch_dataset, batch_size=batch_size, shuffle=False) # Keep shuffle=False for validation


print("PyTorch IterableDatasets and DataLoaders created from split and shuffled tf.data.Dataset.")
print(f"Approximate number of training examples: {train_size}")
print(f"Approximate number of validation examples: {validation_size}")
print(f"Batch size: {batch_size}")
print("DataLoaders are ready for iteration.")
# Out:
# Total number of examples in the 'train' split: 23262
# PyTorch IterableDatasets and DataLoaders created from split and shuffled tf.data.Dataset.
# Approximate number of training examples: 18609
# Approximate number of validation examples: 4653
# Batch size: 32
# DataLoaders are ready for iteration.

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self, num_classes=2):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.dropout = nn.Dropout(0.5)

        # Calculate the size of the flattened layer
        # Assuming input image size is 128x128 after transforms
        # After conv1 (128 -> 128), pool (128 -> 64)
        # After conv2 (64 -> 64), pool (64 -> 32)
        # After conv3 (32 -> 32), pool (32 -> 16)
        self.fc1 = nn.Linear(128 * 16 * 16, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 16 * 16) # Flatten the tensor
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Instantiate the model
model = SimpleCNN(num_classes=2)

print("CNN model defined and instantiated.")
# Out:
# CNN model defined and instantiated.

# %%
import torch.nn as nn
import torch.optim as optim

# Define the loss function (Cross-Entropy Loss)
criterion = nn.CrossEntropyLoss()

# Define the optimizer (Adam)
# Assuming 'model' variable is available from the previous step
optimizer = optim.Adam(model.parameters(), lr=0.001)

print("Loss function (CrossEntropyLoss) and optimizer (Adam) defined.")
# Out:
# Loss function (CrossEntropyLoss) and optimizer (Adam) defined.

# %%
import torch

# Set the number of training epochs
num_epochs = 10

# Move model to the appropriate device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print(f"Training on device: {device}")

# Initialize lists to store metrics for plotting
training_losses_batch = [] # Store training loss every 100 batches
training_losses_epoch = [] # Store average training loss per epoch
validation_losses_epoch = [] # Store validation loss per epoch
training_accuracies_epoch = [] # Store training accuracy per epoch
validation_accuracies_epoch = [] # Store validation accuracy per epoch


# Iterate through the specified number of epochs
for epoch in range(num_epochs):
    # Set the model to training mode
    model.train()
    running_loss = 0.0
    correct_train_predictions = 0
    total_train_samples = 0
    batch_count = 0 # Keep track of the number of batches processed in the epoch


    # Iterate through the training data loader in batches
    for i, (inputs, labels) in enumerate(train_loader):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward propagation
        loss.backward()

        # Update the model's weights
        optimizer.step()

        # Accumulate running loss and track correct predictions
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += labels.size(0)
        correct_train_predictions += (predicted == labels).sum().item()
        batch_count += 1 # Increment batch count


        # Print loss at regular intervals (e.g., every 100 batches)
        if (i + 1) % 100 == 0:
            # Estimate total batches if possible, otherwise print based on index
            try:
                total_batches = len(train_loader)
            except TypeError:
                total_batches = "N/A (IterableDataset)"

            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_batches}], Loss: {running_loss / 100:.4f}')
            # Append the average loss for the last 100 batches to the list
            training_losses_batch.append(running_loss / 100)
            running_loss = 0.0


    # Calculate and store the average loss and accuracy for the training epoch
    average_epoch_train_loss = running_loss / (batch_count % 100 or 100) if batch_count > 0 else 0.0
    epoch_train_accuracy = 100 * correct_train_predictions / total_train_samples if total_train_samples > 0 else 0.0
    training_losses_epoch.append(average_epoch_train_loss)
    training_accuracies_epoch.append(epoch_train_accuracy)

    print(f'Epoch [{epoch+1}/{num_epochs}] finished. Average Training Loss: {average_epoch_train_loss:.4f}, Training Accuracy: {epoch_train_accuracy:.2f}%')

    # --- Validation Phase ---
    model.eval() # Set the model to evaluation mode
    running_validation_loss = 0.0
    correct_validation_predictions = 0
    total_validation_samples = 0

    with torch.no_grad(): # Disable gradient calculation for validation
        for inputs, labels in validation_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_validation_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_validation_samples += labels.size(0)
            correct_validation_predictions += (predicted == labels).sum().item()

    # Calculate and store validation loss and accuracy
    # For IterableDataset, calculate average loss by dividing by the number of samples
    average_epoch_validation_loss = running_validation_loss / total_validation_samples if total_validation_samples > 0 else 0.0
    epoch_validation_accuracy = 100 * correct_validation_predictions / total_validation_samples if total_validation_samples > 0 else 0.0
    validation_losses_epoch.append(average_epoch_validation_loss)
    validation_accuracies_epoch.append(epoch_validation_accuracy)

    print(f'Epoch [{epoch+1}/{num_epochs}] finished. Average Validation Loss: {average_epoch_validation_loss:.4f}, Validation Accuracy: {epoch_validation_accuracy:.2f}%')
    print("-" * 50) # Separator for epochs


print("Training and Validation finished.")
# Out:
# Training on device: cuda
# Epoch [1/10], Step [100/N/A (IterableDataset)], Loss: 0.7014
# Epoch [1/10], Step [200/N/A (IterableDataset)], Loss: 0.6652
# Epoch [1/10], Step [300/N/A (IterableDataset)], Loss: 0.6379
# Epoch [1/10], Step [400/N/A (IterableDataset)], Loss: 0.6013
# Epoch [1/10], Step [500/N/A (IterableDataset)], Loss: 0.5885
# Epoch [1/10] finished. Average Training Loss: 0.5688, Training Accuracy: 63.61%
# Epoch [1/10] finished. Average Validation Loss: 0.0167, Validation Accuracy: 71.95%
# --------------------------------------------------
# Epoch [2/10], Step [100/N/A (IterableDataset)], Loss: 0.5725
# Epoch [2/10], Step [200/N/A (IterableDataset)], Loss: 0.5532
# Epoch [2/10], Step [300/N/A (IterableDataset)], Loss: 0.5338
# Epoch [2/10], Step [400/N/A (IterableDataset)], Loss: 0.5369
# Epoch [2/10], Step [500/N/A (IterableDataset)], Loss: 0.5198
# Epoch [2/10] finished. Average Training Loss: 0.5163, Training Accuracy: 72.76%
# Epoch [2/10] finished. Average Validation Loss: 0.0147, Validation Accuracy: 77.26%
# --------------------------------------------------
# Epoch [3/10], Step [100/N/A (IterableDataset)], Loss: 0.4982
# Epoch [3/10], Step [200/N/A (IterableDataset)], Loss: 0.4958
# Epoch [3/10], Step [300/N/A (IterableDataset)], Loss: 0.4670
# Epoch [3/10], Step [400/N/A (IterableDataset)], Loss: 0.4693
# Epoch [3/10], Step [500/N/A (IterableDataset)], Loss: 0.4556
# Epoch [3/10] finished. Average Training Loss: 0.4578, Training Accuracy: 77.42%
# Epoch [3/10] finished. Average Validation Loss: 0.0135, Validation Accuracy: 80.38%
# --------------------------------------------------
# Epoch [4/10], Step [100/N/A (IterableDataset)], Loss: 0.4220
# Epoch [4/10], Step [200/N/A (IterableDataset)], Loss: 0.4286
# Epoch [4/10], Step [300/N/A (IterableDataset)], Loss: 0.4185
# Epoch [4/10], Step [400/N/A (IterableDataset)], Loss: 0.4098
# Epoch [4/10], Step [500/N/A (IterableDataset)], Loss: 0.3910
# Epoch [4/10] finished. Average Training Loss: 0.3936, Training Accuracy: 81.21%
# Epoch [4/10] finished. Average Validation Loss: 0.0123, Validation Accuracy: 82.36%
# --------------------------------------------------
# Epoch [5/10], Step [100/N/A (IterableDataset)], Loss: 0.3595
# Epoch [5/10], Step [200/N/A (IterableDataset)], Loss: 0.3683
# Epoch [5/10], Step [300/N/A (IterableDataset)], Loss: 0.3359
# Epoch [5/10], Step [400/N/A (IterableDataset)], Loss: 0.3373
# Epoch [5/10], Step [500/N/A (IterableDataset)], Loss: 0.3396
# Epoch [5/10] finished. Average Training Loss: 0.3532, Training Accuracy: 84.32%
# Epoch [5/10] finished. Average Validation Loss: 0.0118, Validation Accuracy: 83.37%
# --------------------------------------------------
# Epoch [6/10], Step [100/N/A (IterableDataset)], Loss: 0.3054
# Epoch [6/10], Step [200/N/A (IterableDataset)], Loss: 0.2990
# Epoch [6/10], Step [300/N/A (IterableDataset)], Loss: 0.2965
# Epoch [6/10], Step [400/N/A (IterableDataset)], Loss: 0.2819
# Epoch [6/10], Step [500/N/A (IterableDataset)], Loss: 0.2845
# Epoch [6/10] finished. Average Training Loss: 0.2921, Training Accuracy: 87.59%
# Epoch [6/10] finished. Average Validation Loss: 0.0116, Validation Accuracy: 84.42%
# --------------------------------------------------
# Epoch [7/10], Step [100/N/A (IterableDataset)], Loss: 0.2337
# Epoch [7/10], Step [200/N/A (IterableDataset)], Loss: 0.2593
# Epoch [7/10], Step [300/N/A (IterableDataset)], Loss: 0.2265
# Epoch [7/10], Step [400/N/A (IterableDataset)], Loss: 0.2222
# Epoch [7/10], Step [500/N/A (IterableDataset)], Loss: 0.1832
# Epoch [7/10] finished. Average Training Loss: 0.2356, Training Accuracy: 90.69%
# Epoch [7/10] finished. Average Validation Loss: 0.0127, Validation Accuracy: 83.62%
# --------------------------------------------------
# Epoch [8/10], Step [100/N/A (IterableDataset)], Loss: 0.1689
# Epoch [8/10], Step [200/N/A (IterableDataset)], Loss: 0.1801
# Epoch [8/10], Step [300/N/A (IterableDataset)], Loss: 0.1667
# Epoch [8/10], Step [400/N/A (IterableDataset)], Loss: 0.1718
# Epoch [8/10], Step [500/N/A (IterableDataset)], Loss: 0.1450
# Epoch [8/10] finished. Average Training Loss: 0.1861, Training Accuracy: 93.41%
# Epoch [8/10] finished. Average Validation Loss: 0.0129, Validation Accuracy: 85.56%
# --------------------------------------------------
# Epoch [9/10], Step [100/N/A (IterableDataset)], Loss: 0.1345
# Epoch [9/10], Step [200/N/A (IterableDataset)], Loss: 0.1235
# Epoch [9/10], Step [300/N/A (IterableDataset)], Loss: 0.1228
# Epoch [9/10], Step [400/N/A (IterableDataset)], Loss: 0.1243
# Epoch [9/10], Step [500/N/A (IterableDataset)], Loss: 0.1187
# Epoch [9/10] finished. Average Training Loss: 0.1576, Training Accuracy: 94.86%
# Epoch [9/10] finished. Average Validation Loss: 0.0135, Validation Accuracy: 84.53%
# --------------------------------------------------
# Epoch [10/10], Step [100/N/A (IterableDataset)], Loss: 0.1185
# Epoch [10/10], Step [200/N/A (IterableDataset)], Loss: 0.0970
# Epoch [10/10], Step [300/N/A (IterableDataset)], Loss: 0.1053
# Epoch [10/10], Step [400/N/A (IterableDataset)], Loss: 0.1049
# Epoch [10/10], Step [500/N/A (IterableDataset)], Loss: 0.0872
# Epoch [10/10] finished. Average Training Loss: 0.1367, Training Accuracy: 96.02%
# Epoch [10/10] finished. Average Validation Loss: 0.0150, Validation Accuracy: 84.85%
# --------------------------------------------------
# Training and Validation finished.

# %%
import matplotlib.pyplot as plt

# Check if all necessary variables are available
if all(var in globals() for var in ['training_losses_epoch', 'validation_losses_epoch',
                                    'training_accuracies_epoch', 'validation_accuracies_epoch']):
    epochs = range(1, len(training_losses_epoch) + 1)

    # Plot Loss graph
    plt.figure(figsize=(8, 5))
    plt.plot(epochs, training_losses_epoch, label='Training Loss')
    plt.plot(epochs, validation_losses_epoch, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss per Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot Accuracy graph
    plt.figure(figsize=(8, 5))
    plt.plot(epochs, training_accuracies_epoch, label='Training Accuracy')
    plt.plot(epochs, validation_accuracies_epoch, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy per Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

else:
    print("Some required variables are missing. Please make sure training_losses_epoch, validation_losses_epoch, training_accuracies_epoch, and validation_accuracies_epoch are all recorded.")
